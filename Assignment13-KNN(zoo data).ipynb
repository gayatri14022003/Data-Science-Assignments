# %% [markdown]
# KNN Zoo data

# %% [markdown]
# Q1] Implement a KNN model to classify the animals in to categorie

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
sns.set()

# %%
zoo=pd.read_csv("/content/Zoo.csv")
zoo.head()
# Out:
#   animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    type
# 0     1
# 1     1
# 2     4
# 3     1
# 4     1

# %%
zoo.isnull().any()
# Out:
# animal name    False
# hair           False
# feathers       False
# eggs           False
# milk           False
# airborne       False
# aquatic        False
# predator       False
# toothed        False
# backbone       False
# breathes       False
# venomous       False
# fins           False
# legs           False
# tail           False
# domestic       False
# catsize        False
# type           False
# dtype: bool

# %%
zoo.isnull().sum()
# Out:
# animal name    0
# hair           0
# feathers       0
# eggs           0
# milk           0
# airborne       0
# aquatic        0
# predator       0
# toothed        0
# backbone       0
# breathes       0
# venomous       0
# fins           0
# legs           0
# tail           0
# domestic       0
# catsize        0
# type           0
# dtype: int64

# %%
#descriptive statistics
zoo.shape
# Out:
# (101, 18)

# %%
zoo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   animal name  101 non-null    object
#  1   hair         101 non-null    int64
#  2   feathers     101 non-null    int64
#  3   eggs         101 non-null    int64
#  4   milk         101 non-null    int64
#  5   airborne     101 non-null    int64
#  6   aquatic      101 non-null    int64
#  7   predator     101 non-null    int64
#  8   toothed      101 non-null    int64
#  9   backbone     101 non-null    int64
#  10  breathes     101 non-null    int64
#  11  venomous     101 non-null    int64
#  12  fins         101 non-null    int64
#  13  legs         101 non-null    int64
#  14  tail         101 non-null    int64
#  15  domestic     101 non-null    int64
#  16  catsize      101 non-null    int64
#  17  type         101 non-null    int64
# dtypes: int64(17), object(1)
# ...

# %%
zoo[zoo.duplicated()]
#there are no duplicated values present
# Out:
# Empty DataFrame
# Columns: [animal name, hair, feathers, eggs, milk, airborne, aquatic, predator, toothed, backbone, breathes, venomous, fins, legs, tail, domestic, catsize, type]
# Index: []

# %%
zoo.describe()
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    backbone    breathes    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# ...

# %%
list(zoo)
# Out:
# ['animal name',
#  'hair',
#  'feathers',
#  'eggs',
#  'milk',
#  'airborne',
#  'aquatic',
#  'predator',
#  'toothed',
#  'backbone',
#  'breathes',
#  'venomous',
#  'fins',
#  'legs',
#  'tail',
#  'domestic',
#  'catsize',
#  'type']

# %%
#data visualization
fig, ax = plt.subplots(figsize=(15,6))
sns.heatmap(zoo.corr(), annot=True, fmt='.1g', cmap="viridis", cbar=False, linewidths=0.5, linecolor='black')
# Out:
# <Axes: >

# %%
zoo_df = zoo.copy()
zoo_df['has_legs'] = np.where(zoo_df['legs']>0,1,0)
zoo_df = zoo_df[['animal name','hair','feathers','eggs','milk', 'airborne', 'aquatic', 'predator', 'toothed', 'backbone', 'breathes','venomous','fins','legs','has_legs','tail','domestic','catsize']]
zoo_df.head()
# Out:
#   animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  has_legs  tail  \
# 0        1         1         1         0     0     4         1     0
# 1        1         1         1         0     0     4         1     1
# 2        1         1         0         0     1     0         0     1
# 3        1         1         1         0     0     4         1     0
# 4        1         1         1         0     0     4         1     1
#
#    domestic  catsize
# 0         0        1
# 1         0        1
# 2         0        0
# 3         0        1
# ...

# %%
zoo.columns
# Out:
# Index(['animal name', 'hair', 'feathers', 'eggs', 'milk', 'airborne',
#        'aquatic', 'predator', 'toothed', 'backbone', 'breathes', 'venomous',
#        'fins', 'legs', 'tail', 'domestic', 'catsize', 'type'],
#       dtype='object')

# %%
plt.figure(figsize=(16,6))
sns.barplot( data=zoo, width=0.8)
plt.plot()
# Out:
# []

# %%
zoo.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
zoo.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
cor=zoo.corr()

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d9fe0_row0_col0, #T_d9fe0_row1_col1, #T_d9fe0_row2_col2, #T_d9fe0_row3_col3, #T_d9fe0_row4_col4, #T_d9fe0_row5_col5, #T_d9fe0_row6_col6, #T_d9fe0_row7_col7, #T_d9fe0_row8_col8, #T_d9fe0_row9_col9, #T_d9fe0_row10_col10, #T_d9fe0_row11_col11, #T_d9fe0_row12_col12, #T_d9fe0_row13_col13, #T_d9fe0_row14_col14, #T_d9fe0_row15_col15, #T_d9fe0_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d9fe0_row0_col1, #T_d9fe0_row0_col10 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_d9fe0_row0_col2, #T_d9fe0_row5_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d9fe0_row0_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_d9fe0_row0_col4, #T_d9fe0_row1_col12 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_d9fe0_row0_col5, #T_d9fe0_row9_col10, #T_d9fe0_row16_col14 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d9fe0_row0_col6, #T_d9fe0_row2_col14 {
# ...

# %%
#knn finding the optimal no of k
X = zoo.iloc[:,1:17]
y = zoo.iloc[:,17]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []

# %%
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_accuracy.append(knn.score(X_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %%
# drawing the graph with k=5 so we can achive accuracy upto 90%

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)

# %%
scores = []
cv_scores = []

# %%
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
score_knn=cross_val_score(knn, X,y, cv=10)

# %%
score_knn.mean()
# Out:
# 0.8809090909090909

# %%
score_knn.std()*2
# Out:
# 0.12072782037115655

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)
cv_scores
# Out:
# [0.8809090909090909]

# %%
#conclusion accuracy of svm is 0.90%
