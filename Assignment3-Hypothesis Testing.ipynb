# %% [markdown]
# # Hypothesis testing-Cutlets data

# %% [markdown]
# Q1]A F&B manager wants to determine whether there is any significant difference in the diameter of the cutlet between two units. A randomly selected sample of cutlets was collected from both units and measured? Analyze the data and draw inferences at 5% significance level. Please state the assumptions and tests that you carried out to check validity of the assumptions.
#      Minitab File : Cutlets.mtw
#
#
# 	Null hypothesis H0= mu1=mu2
# Alternate hypothesis H1=mu1 != mu2
# Alpha=0.05%
# Significance=5%

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import statsmodels.api as sm
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("C:\\Users\\hp\\Downloads\\Cutlets.csv")
data.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
data.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %%
plt.subplots(figsize=(6,3))
plt.subplot(121)
plt.boxplot(data['Unit A'])
plt.title("Unit A")
plt.plot()
plt.subplot(122)
plt.boxplot(data['Unit B'])
plt.title("Unit B")
plt.plot()
# Out:
# []

# %%
plt.subplots(figsize=(6,3))
plt.subplot(121)
plt.hist(data['Unit A'],edgecolor='black', linewidth=2)
plt.plot()
plt.subplot(122)
plt.hist(data['Unit B'],edgecolor='black',linewidth=2)
plt.plot()
# Out:
# []

# %%
plt.title("Unit A vs Unit B")
sns.distplot(data['Unit A'])
plt.plot()
sns.distplot(data['Unit B'])
labels=['Unit A','Unit B']
plt.legend(labels)
plt.plot()
# Out:
# []

# %%
sm.qqplot(data['Unit A'],line= 'q')
plt.title("Unit A")
plt.plot()
sm.qqplot(data['Unit B'],line='q')
plt.title("Unit B")
plt.plot()
# Out:
# []

# %%
statistics,p_value=stats.ttest_ind(data['Unit A'],data['Unit B'],alternative="two-sided")
print("p_ value=",p_value)
# Out:
# p_ value= 0.4722394724599501

# %%
alpha=0.025
if(alpha<=p_value):
    print("We are rejecting null hypothesis")
else:
    print("We are accepting null hypothesis")
# Out:
# We are rejecting null hypothesis

# %%
# q2

# %%
tat=pd.read_csv("C:\\Users\\hp\\Downloads\\LabTAT.csv")
tat.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
tat.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
tat.isnull().sum()
# Out:
# Laboratory 1    0
# Laboratory 2    0
# Laboratory 3    0
# Laboratory 4    0
# dtype: int64

# %%
plt.subplots(figsize=(8,8))
plt.subplot(221)
plt.boxplot(tat['Laboratory 1'])
plt.plot()

plt.subplot(222)
plt.boxplot(tat['Laboratory 2'])
plt.plot()


plt.subplot(223)
plt.boxplot(tat['Laboratory 3'])
plt.plot()

plt.subplot(224)
plt.boxplot(tat['Laboratory 4'])
plt.plot()
# Out:
# []

# %%
plt.subplots(figsize=(8,8))
plt.subplot(221)
plt.hist(tat['Laboratory 1'],edgecolor='black',linewidth=2)
plt.subplot(222)
plt.hist(tat['Laboratory 2'],edgecolor='black', linewidth=2)
plt.subplot(223)
plt.hist(tat['Laboratory 3'],edgecolor='black',linewidth=2)
plt.subplot(224)
plt.hist(tat['Laboratory 4'],edgecolor='black',linewidth=2)
plt.plot()
# Out:
# []

# %%
sm.qqplot(tat['Laboratory 1'],line='q')
sm.qqplot(tat['Laboratory 2'],line='q')
sm.qqplot(tat['Laboratory 3'],line='q')
sm.qqplot(tat['Laboratory 4'],line='q')

# %%
statistics , p_value=stats.f_oneway(tat['Laboratory 1'], tat['Laboratory 2'], tat['Laboratory 3'],tat['Laboratory 4'] )
print("p_value=",p_value)
# Out:
# p_value= 2.1156708949992414e-57

# %%
alpha=0.05
if(alpha<=p_value):
    print("we are rejecting null hypothesis There is significance diffrence of avarage TAT")
else:
    print("we are accepting null hypothesis there is a no significance diffrence between TAT")
# Out:
# we are accepting null hypothesis there is a no significance diffrence between TAT

# %%
#q3

# %%
from scipy.stats import chi2_contingency
buyer=pd.read_csv("C:\\Users\\hp\\Downloads\\BuyerRatio.csv")
buyer.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
table=[[50,142,131,70],[550,351,480,350]]

# %%
stat, p, dof, expected = stats.chi2_contingency(table)
print("stats=",stat,"\np_value=",p,"\ndoc=",dof,"\nexp=",expected)
# Out:
# stats= 80.27295426602495
# p_value= 2.682172557281901e-17
# doc= 3
# exp= [[111.01694915  91.21892655 113.05225989  77.71186441]
#  [488.98305085 401.78107345 497.94774011 342.28813559]]

# %%
observed=np.array([50,142,131,70,550,351,480,350])
expected=np.array([111.01694915,91.21892655,113.05225989,77.71186441,488.98305085,401.78107345,497.94774011, 342.28813559])

# %%
statistics,p_value=stats.chisquare(observed,expected,ddof=3)
print("statistics=",statistics,"\np_value=",p_value)
# Out:
# statistics= 80.27295426893663
# p_value= 1.5246724541776732e-16

# %%
alpha=0.05
if(alpha<=p_value):
    print("we are rejecting null hypothesis ")
else:
    print("we are accepting null hypothesis ")
# Out:
# we are accepting null hypothesis

# %%
#q4

# %%
data=pd.read_csv("C:\\Users\\hp\\Downloads\\Costomer+OrderForm.csv")
data.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Phillippines  300 non-null    object
#  1   Indonesia     300 non-null    object
#  2   Malta         300 non-null    object
#  3   India         300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %%
data.describe()
# Out:
#        Phillippines   Indonesia       Malta       India
# count           300         300         300         300
# unique            2           2           2           2
# top      Error Free  Error Free  Error Free  Error Free
# freq            271         267         269         280

# %%
print((data.isnull()).sum())
# Out:
# Phillippines    0
# Indonesia       0
# Malta           0
# India           0
# dtype: int64

# %%
print("Phillippines=",data['Phillippines'].value_counts(),"\nIndonesia=",data['Indonesia'].value_counts(),
      "\nMalta=",data['Malta'].value_counts(),"\nIndia=",data['India'].value_counts())
# Out:
# Phillippines= Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64
# Indonesia= Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64
# Malta= Error Free    269
# Defective      31
# Name: Malta, dtype: int64
# India= Error Free    280
# Defective      20
# Name: India, dtype: int64

# %%
contigency_table=[[271,267,269,280],[29,33,31,20]]

# %%
stat, p, dof, expected = stats.chi2_contingency(table)
print("stats=",stat,"\np_value=",p,"\ndoc=",dof,"\nexp=",expected)
# Out:
# stats= 80.27295426602495
# p_value= 2.682172557281901e-17
# doc= 3
# exp= [[111.01694915  91.21892655 113.05225989  77.71186441]
#  [488.98305085 401.78107345 497.94774011 342.28813559]]

# %%
obs=[271,267,269,280,29,33,31,20]
expec=[111.01694915, 91.21892655, 113.05225989 , 77.71186441, 488.98305085, 401.78107345, 497.94774011, 342.28813559]

# %%
alpha=0.05
if(alpha<=p_value):
    print("we are rejecting null hypothesis ")
else:
    print("we are accepting null hypothesis ")
# Out:
# we are accepting null hypothesis
